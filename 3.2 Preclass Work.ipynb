# %% [markdown]
# Plotting the level set of a function

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X + Y )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# /Users/jacob/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + 4*Y**2 )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X * Y )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# /Users/jacob/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 - Y**2 )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# /Users/jacob/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**2 + 2*X*Y + Y**2 )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# /Users/jacob/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
X, Y = np.meshgrid(xlist, ylist)
Z = np.sqrt(X**4 + 2*X*Y + Y**4 )

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# /Users/jacob/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in sqrt
#   import sys

# %%
import numpy as np
import matplotlib.pyplot as plt

xlist = np.linspace(-3.0, 3.0, 100)
ylist = np.linspace(-3.0, 3.0, 100)
zlist = np.linspace(-3.0, 3.0, 100)
X, Y, Z = np.meshgrid(xlist, ylist, zlist)
Z = np.sqrt(np.exp(X**2 + Y**2 + Z**2))

plt.figure()
levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
contour = plt.contour(X, Y, Z, levels, colors='k')
plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
contour_filled = plt.contourf(X, Y, Z, levels)
plt.colorbar(contour_filled)
plt.title('Plot from level list')
plt.xlabel('x (cm)')
plt.ylabel('y (cm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-39566134ac6d> in <module>
#      10 plt.figure()
#      11 levels = [0.0, 0.2, 0.5, 0.9, 1.5, 2.5, 3.5]
# ---> 12 contour = plt.contour(X, Y, Z, levels, colors='k')
#      13 plt.clabel(contour, colors = 'k', fmt = '%2.1f', fontsize=12)
#      14 contour_filled = plt.contourf(X, Y, Z, levels)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in contour(data, *args, **kwargs)
#    2537     __ret = gca().contour(
#    2538         *args, **({"data": data} if data is not None else {}),
# -> 2539         **kwargs)
#    2540     if __ret._A is not None: sci(__ret)  # noqa
#    2541     return __ret
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in contour(self, *args, **kwargs)
#    6229     def contour(self, *args, **kwargs):
#    6230         kwargs['filled'] = False
# -> 6231         contours = mcontour.QuadContourSet(self, *args, **kwargs)
#    6232         self.autoscale_view()
#    6233         return contours
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, *args, **kwargs)
#     885         self._transform = kwargs.pop('transform', None)
#     886
# --> 887         kwargs = self._process_args(*args, **kwargs)
#     888         self._process_levels()
#     889
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py in _process_args(self, *args, **kwargs)
#    1491                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1492
# -> 1493             x, y, z = self._contour_args(args, kwargs)
#    1494
#    1495             _mask = ma.getmask(z)
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py in _contour_args(self, args, kwargs)
#    1549             args = args[1:]
#    1550         elif Nargs <= 4:
# -> 1551             x, y, z = self._check_xyz(args[:3], kwargs)
#    1552             args = args[3:]
#    1553         else:
#
# ~/miniconda3/lib/python3.7/site-packages/matplotlib/contour.py in _check_xyz(self, args, kwargs)
#    1583
#    1584         if z.ndim != 2:
# -> 1585             raise TypeError("Input z must be a 2D array.")
#    1586         elif z.shape[0] < 2 or z.shape[1] < 2:
#    1587             raise TypeError("Input z must be at least a 2x2 array.")
#
# TypeError: Input z must be a 2D array.
